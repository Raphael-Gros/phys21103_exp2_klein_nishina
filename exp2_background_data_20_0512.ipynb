# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
#Loads the data from the scattered spectrum for the angle in question

channel, E, N = np.loadtxt('Archive/20_scatt_0512.tsv', unpack=True, skiprows=25)

#Converts counts into rate

R_scatt = N/2559.11

#Computes uncertainty for rate

dR_scatt = np.sqrt(N)/2559.11
for i, value in enumerate(dR_scatt):
    if value == 0:
        dR_scatt[i] = 1.14

# %%
#Loads the data from the background spectrum for the angle in question

channel_bkg, E_bkg, N_bkg = np.loadtxt('Archive 2/20_bkg_0512.tsv', unpack=True, skiprows=25)

#Converts counts into rate

R_bkg = N_bkg/1813.08

#Computes uncertainty for rate

dR_bkg = np.sqrt(N_bkg)/1813.08
for i, value in enumerate(dR_bkg):
    if value == 0:
        dR_bkg[i] = 1.14

# %%
#Subtracts the background from the scattered spectrum

R_bkg_sub = R_scatt - (R_bkg)

#Computes the uncertainty for the background subtracted spectrum

dR_bkg_sub = np.sqrt(dR_scatt**2+dR_bkg**2)
for i, value in enumerate(dR_bkg_sub):
    if value == 0:
        dR_bkg_sub[i] = 1.14

# %%
#Plots the scattered spectrum

fig = plt.figure()
ax = fig.add_subplot(111)
ax.errorbar(channel, R_scatt, dR_scatt, fmt='k.')
ax.axis([min(channel)-10,max(channel)+10,min(R_scatt)-.1,max(R_scatt)+.1])
ax.set_title('PHA Energy Spectrum for Cs-137 Scattering at 20$^\\circ$')
ax.set_xlabel('Channel')
ax.set_ylabel('Rate (counts/sec)')

plt.savefig('Exp2_20_scatt_0512.pdf')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Plots the background spectrum

fig = plt.figure()
ax = fig.add_subplot(111)
ax.errorbar(channel_bkg, R_bkg, dR_bkg, fmt='k.')
ax.axis([min(channel)-10,max(channel)+10,min(R_bkg)-.1,max(R_scatt)+.1])
ax.set_title('PHA Energy Spectrum for Cs-137 Background at 20$^\\circ$')
ax.set_xlabel('Channel')
ax.set_ylabel('Rate (counts/sec)')

plt.savefig('Exp2_20_scatt_0512_bkg.pdf')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Plots the background subtracted scattered spectrum

fig = plt.figure()
ax = fig.add_subplot(111)
ax.errorbar(channel, R_bkg_sub, dR_bkg_sub, fmt='k.')
ax.axis([min(channel)-10,max(channel)+10,min(R_bkg_sub)-.1,max(R_scatt)+.1])
ax.set_title('PHA Energy Spectrum for Cs-137 Scattering \n with Background Substitution at 20$^\\circ$')
ax.set_xlabel('Channel')
ax.set_ylabel('Rate (counts/sec)')

plt.savefig('Exp2_20_scatt_0512_bkg_sub.pdf')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Creating a fit for the background peak

def fitfunc(p,x):
    return (p[0]/(p[2]*np.sqrt(2*np.pi)))*np.exp(-(x-p[1])**2/((p[2]**2)*2))+p[3]+p[4]*x
def residual(p, x, y, err):
    return (fitfunc(p, x)-y)/err

p0 = [5000., 800., 30., 500., 3]


# Sets the lower and upper bounds of the region of interest

b=695
t=880

channel2 = channel[b:t]
N2 = R_bkg[b:t]
dN2 = dR_bkg[b:t]
pf, cov, info, mesg, success = optimize.leastsq(residual, p0, args=(channel2, N2, dN2),
                                                full_output=1)

if cov is None:
    print('Fit did not converge')
    print('Success code:', success)
    print(mesg)
else:
    chisq = sum(info['fvec']*info['fvec'])
    dof = len(channel2) - len(pf)
    pferr = [np.sqrt(cov[i,i]) for i in range(len(pf))]
    print('Converged with chi-squared', chisq)
    print('Number of degrees of freedom, dof =', dof)
    print('Reduced chi-squared ', chisq/dof)
    print('Inital guess values:')
    print('  p0 =', p0)
    print('Best fit values:')
    print('  pf =', pf)
    print('Uncertainties in the best fit values:')
    print('  pferr =', pferr)
    
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(channel, R_bkg, 'k.')
ax.plot(channel2, N2, 'r.', label='Data in fit')

    
# We then plot the fit function. We could plot it at each point in "channel2"
#  and connect those points with straight lines. However, we may want a smoother
#  plot. To do so, we create a new array of points using "linspace()" that covers
#  the same range, but more densely. When we connect these points, the line will
#  be more smooth.
CHANNEL = np.linspace(min(channel2), max(channel2), 5000)
ax.plot(CHANNEL, fitfunc(pf, CHANNEL), 'r-', label='Fit')

ax.axis([-10,1030,min(R_bkg)-0.1,max(R_bkg)+0.1])
ax.set_title('PHA Energy Spectrum for Cs-137 Background at 20$^\\circ$ Fit')
ax.set_xlabel('Channel')
ax.set_ylabel('Rate (counts/sec)')
ax.legend()

textfit1 = '$f(x) = N/( \\sigma\\sqrt{2\\pi})exp[-(x-\\mu)^2/2\\sigma^2]$ \n $+a+bx$ \n' \
               '$N = %.2f \pm %.2f$ counts/sec \n' \
               '$\\mu = %.1f \pm %.1f$ channel \n' \
               '$\\sigma = %.1f \pm %.1f$ channel \n' \
               '$a = %.3f \pm %.3f$ counts/sec \n' \
               '$b = %.6f \pm %.6f$ counts/sec/channel \n' \
                '$\chi^2= %.2f$ \n' \
               '$N = %i$ (dof) \n' \
               '$\chi^2/N = %.2f$' \
                % (pf[0], pferr[0], pf[1], pferr[1], pf[2], pferr[2], 
                   pf[3], pferr[3], pf[4], pferr[4], chisq, dof, chisq/dof)
ax.text(0.1, .85, textfit1, transform=ax.transAxes, fontsize=8,
             verticalalignment='top')

plt.savefig('Exp2_20_bkg_0512_fit.pdf')
plt.show()
# Out:
# Converged with chi-squared 195.75731769877453
# Number of degrees of freedom, dof = 180
# Reduced chi-squared  1.0875406538820807
# Inital guess values:
#   p0 = [5000.0, 800.0, 30.0, 500.0, 3]
# Best fit values:
#   pf = [ 8.20742689e+00  7.91476466e+02  2.87316352e+01  7.14352396e-02
#  -6.79742488e-05]
# Uncertainties in the best fit values:
#   pferr = [0.1266931052393307, 0.35612127647228004, 0.39515124762064147, 0.004707573219117865, 5.904943431528248e-06]
# <img src="data:image/png;base64,..." width="640">

# %%
#Creating a fit for the background subtracted scattered spectrum

def fitfunc(p,x):
    return (p[0]/(p[2]*np.sqrt(2*np.pi)))*np.exp(-(x-p[1])**2/((p[2]**2)*2))+p[3]+p[4]*x
def residual(p, x, y, err):
    return (fitfunc(p, x)-y)/err

p0 = [5000., 766., 30., 100., 0.1]

# Sets the lower and upper bounds of the region of interest

b=673
t=840

channel2 = channel[b:t]
N2 = R_bkg_sub[b:t]
dN2 = dR_bkg_sub[b:t]
pf, cov, info, mesg, success = optimize.leastsq(residual, p0, args=(channel2, N2, dN2),
                                                full_output=1)

if cov is None:
    print('Fit did not converge')
    print('Success code:', success)
    print(mesg)
else:
    chisq = sum(info['fvec']*info['fvec'])
    dof = len(channel2) - len(pf)
    pferr = [np.sqrt(cov[i,i]) for i in range(len(pf))]
    print('Converged with chi-squared', chisq)
    print('Number of degrees of freedom, dof =', dof)
    print('Reduced chi-squared ', chisq/dof)
    print('Inital guess values:')
    print('  p0 =', p0)
    print('Best fit values:')
    print('  pf =', pf)
    print('Uncertainties in the best fit values:')
    print('  pferr =', pferr)
    
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(channel, R_bkg_sub, 'k.')
ax.plot(channel2, N2, 'r.', label='Data in fit')

    
# We then plot the fit function. We could plot it at each point in "channel2"
#  and connect those points with straight lines. However, we may want a smoother
#  plot. To do so, we create a new array of points using "linspace()" that covers
#  the same range, but more densely. When we connect these points, the line will
#  be more smooth.
CHANNEL = np.linspace(min(channel2), max(channel2), 5000)
ax.plot(CHANNEL, fitfunc(pf, CHANNEL), 'r-', label='Fit')

ax.axis([-10,1030,min(R_bkg_sub)-.1,max(R_scatt)+.1])
ax.set_title('PHA Energy Spectrum for Cs-137 Scattering \n with Background Substitution at 20$^\\circ$ Fit')
ax.set_xlabel('Channel')
ax.set_ylabel('Rate (counts/sec)')
ax.legend()

textfit1 = '$f(x) = N/( \\sigma\\sqrt{2\\pi})exp[-(x-\\mu)^2/2\\sigma^2]$ \n $+a+bx$ \n' \
               '$N = %.1f \pm %.1f$ counts/sec \n' \
               '$\\mu = %.1f \pm %.1f$ channel \n' \
               '$\\sigma = %.1f \pm %.1f$ channel \n' \
               '$a = %.3f \pm %.3f$ counts/sec \n' \
               '$b = %.5f \pm %.5f$ counts/sec/channel \n' \
                '$\chi^2= %.2f$ \n' \
               '$N = %i$ (dof) \n' \
               '$\chi^2/N = %.2f$' \
                % (pf[0], pferr[0], pf[1], pferr[1], pf[2], pferr[2], pf[3], pferr[3], pf[4], pferr[4], chisq, dof, chisq/dof)
ax.text(0.1, .75, textfit1, transform=ax.transAxes, fontsize=8,
             verticalalignment='top')

plt.savefig('Exp2_20_scatt_0512_bkg_sub_fit.pdf')
plt.show()
# Out:
# Converged with chi-squared 161.0978039079603
# Number of degrees of freedom, dof = 162
# Reduced chi-squared  0.9944308883207426
# Inital guess values:
#   p0 = [5000.0, 766.0, 30.0, 100.0, 0.1]
# Best fit values:
#   pf = [ 2.10389719e+01  7.56567301e+02  2.84568309e+01  6.77286099e-02
#  -6.14195621e-05]
# Uncertainties in the best fit values:
#   pferr = [0.29262235639308526, 0.273112478609072, 0.3232108077284293, 0.011534294265882865, 1.575187230793941e-05]
# <img src="data:image/png;base64,..." width="640">
